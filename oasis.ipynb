# %%
import pandas as pd

# %%
df = pd.read_csv('oasis.csv')
df
# Out:
#     album_release_date  album_release_year  danceability  energy  key  \
# 0           2024-01-28                2011        0.8792   0.753    4
# 1           2021-06-11                2015        0.7583   0.374   16
# 2           2024-03-19                2020        0.9436   0.493   16
# 3           2023-12-23                2020        0.4703   0.549   14
# 4           2023-07-07                2012        0.2661   0.818    4
# ..                 ...                 ...           ...     ...  ...
# 995         2023-11-21                2017        0.6069   0.670   13
# 996         2022-03-18                2014        0.5212   0.731   18
# 997         2024-02-12                2010        0.3916   0.248   13
# 998         2023-06-10                2008        0.9758   0.001    4
# 999         2021-08-07                2014        0.1783   0.924   18
#
#      loudness  mode  speechiness  acousticness  instrumentalness  disc_number  \
# ...

# %%
df['album_release_date'] = pd.to_datetime(df['album_release_date'])

# %%
df.head()
# Out:
#   album_release_date  album_release_year  danceability  energy  key  loudness  \
# 0         2024-01-28                2011        0.8792   0.753    4  -14.4127
# 1         2021-06-11                2015        0.7583   0.374   16  -54.2046
# 2         2024-03-19                2020        0.9436   0.493   16  -90.4643
# 3         2023-12-23                2020        0.4703   0.549   14  -89.2968
# 4         2023-07-07                2012        0.2661   0.818    4  -52.0703
#
#    mode  speechiness  acousticness  instrumentalness  disc_number  \
# 0     1      0.13994      0.446125          0.762794     5.868635
# 1     1      0.32944      0.168946          0.741761     0.924982
# 2     1      0.69030      0.286437          0.164708     1.259425
# 3     0      0.81751      0.121787          0.496991     5.945936
# 4     1      0.34354      0.758322          0.818938     5.338877
#
#    duration_ms  explicit  is_local     track_name  track_number  \
# ...

# %%
df.query('album_release_date < 2022')
# nombre de los albumes publicados entre 2022 y 2024
# Out:
#     album_release_date  album_release_year  danceability  energy  key  \
# 1           2021-06-11                2015        0.7583   0.374   16
# 5           2021-07-18                   0        0.6989   0.065    3
# 8           2021-05-07                2018        0.0546   0.993   13
# 9           2021-05-04                2014        0.9576   0.927    3
# 14          2021-09-02                2014        0.4915   0.666    1
# ..                 ...                 ...           ...     ...  ...
# 986         2021-10-08                2016        0.6579   0.099    6
# 988         2021-12-03                2011        0.6326   0.067    2
# 989         2021-12-04                2005        0.3411   0.805    6
# 991         2021-08-02                2017        0.6125   0.751    6
# 999         2021-08-07                2014        0.1783   0.924   18
#
#      loudness  mode  speechiness  acousticness  instrumentalness  disc_number  \
# ...

# %%
# nombre de los albumes publicados entre 2022 y 2024
album_names = df.query('2022 <= album_release_date <= 2024')
print(album_names['album_name'].unique())
# Out:
# ['Crystal Waters' 'Midnight Serenade' 'Golden Horizon' 'Moonlit Melodies'
#  'Electric Pulse' 'Wildfire Echoes' 'Velvet Twilight' 'Sunset Dreams'
#  'Neon Nights' 'Starlight Symphony']
