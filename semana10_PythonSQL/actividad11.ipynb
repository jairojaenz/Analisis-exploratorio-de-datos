# %%
# En esta actividad deberán realizar un bivariado y multivariado para los 
# datasets “exercise.csv” y “car_crashes.csv” para lo cual harán uso de: 
# 1.	Scatterplot (diagrama de dispersión)
# 2.	Joinplot 
# 3.	Boxplot
# 4.	Barplot
# 5.	Pairplot
# 6.	Matriz de correlación 
# 7.	Visualización de la matriz de correlación y covarianza


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Cargamos los datasets
exercise = pd.read_csv('exercise.csv')
car_crashes = pd.read_csv('car_crashes.csv')

exercise.head()
car_crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
# Scatterplot (diagrama de dispersión)
# Para el dataset "exercise"
sns.relplot(
    kind='scatter',
    data=exercise,
    x='time',
    y='pulse',
    hue='kind'
)
plt.show()

# %%
# Eliminar 'min' de la columna 'time' y convertir a numérico
exercise['time'] = exercise['time'].str.replace('min', '').astype(float)

# %%
# scatterplot para el dataset "car_crashes"
sns.relplot(
    kind='scatter',
    data=car_crashes,
    x='alcohol',
    y='total',
    hue='abbrev'
)
plt.show()

# %%
# Joinplot
# Para el dataset "exercise"
sns.jointplot(
    data=exercise,
    x='pulse',
    y='time',
    hue='kind',
)

# %%
# Para el dataset "car_crashes"
sns.jointplot(
    data=car_crashes,
    x='alcohol',
    y='total',
    hue='abbrev',
)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/03/fv0q_y693gq6wh4vl8097rqh0000gn/T/ipykernel_5021/2349589780.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
# Boxplot
# Para el dataset "exercise"
sns.boxplot(
    data=exercise,
    x='kind',
    y='pulse'
)
plt.show()

# %%
# Para el dataset "car_crashes"
sns.boxplot(
    data=car_crashes,
    x='abbrev',
    y='total'
)
plt.show()

# %%
# Barplot
# Para el dataset "exercise"
sns.barplot(
    data=exercise,
    x='kind',
    y='pulse'
)
plt.show()

# %%
# Para el dataset "car_crashes"
sns.barplot(
    data=car_crashes,
    x='abbrev',
    y='total'
)
plt.show()

# %%
# Pairplot
# Para el dataset "exercise"
sns.pairplot(
    data=exercise,
    hue='kind',
    corner=True,
    kind='scatter'
)
plt.show()

# %%
# Para el dataset "car_crashes"
sns.pairplot(
    data=car_crashes,
    hue='abbrev',
    corner=True,
    kind='scatter'
)
plt.show()

# %%
# Matriz de correlación
# Para el dataset "exercise"
from sklearn.preprocessing import StandardScaler

exercise = sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
# visualización de la matriz de correlación
sns.pairplot(exercise, hue='kind',corner=True,kind='scatter')
plt.show()

# %%
# Eliminar 'min' de la columna 'time' y convertir a numérico
exercise['time'] = exercise['time'].str.replace('min', '').astype(float)

# %%
exercise.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
# Normalizamos los datos
scaler = StandardScaler()
exercise_scaled = scaler.fit_transform(exercise[['time', 'pulse']])
exercise_scaled
# Out:
# array([[-1.21042749, -0.99487718],
#        [-0.02814948, -0.99487718],
#        [ 1.23857697, -0.79184102],
#        [-1.21042749, -0.65648358],
#        [-0.02814948, -0.52112614],
#        [ 1.23857697, -0.45344742],
#        [-1.21042749, -0.18273254],
#        [-0.02814948, -0.18273254],
#        [ 1.23857697, -0.3857687 ],
#        [-1.21042749, -1.33327078],
#        [-0.02814948, -1.19791334],
#        [ 1.23857697, -1.13023462],
#        [-1.21042749, -0.58880486],
#        [-0.02814948, -0.52112614],
#        [ 1.23857697, -0.58880486],
#        [-1.21042749, -1.13023462],
#        [-0.02814948, -1.13023462],
#        [ 1.23857697, -1.0625559 ],
#        [-1.21042749, -0.85951974],
#        [-0.02814948, -0.79184102],
#        [ 1.23857697, -0.65648358],
#        [-1.21042749, -0.52112614],
#        [-0.02814948, -0.3857687 ],
#        [ 1.23857697, -0.31808998],
#        [-1.21042749, -0.18273254],
#        [-0.02814948, -0.0473751 ],
#        [ 1.23857697, -0.25041126],
# ...

# %%
# Hallar la matriz transpuesta
exercise_scaled.T
# Out:
# array([[-1.21042749, -0.02814948,  1.23857697, -1.21042749, -0.02814948,
#          1.23857697, -1.21042749, -0.02814948,  1.23857697, -1.21042749,
#         -0.02814948,  1.23857697, -1.21042749, -0.02814948,  1.23857697,
#         -1.21042749, -0.02814948,  1.23857697, -1.21042749, -0.02814948,
#          1.23857697, -1.21042749, -0.02814948,  1.23857697, -1.21042749,
#         -0.02814948,  1.23857697, -1.21042749, -0.02814948,  1.23857697,
#         -1.21042749, -0.02814948,  1.23857697, -1.21042749, -0.02814948,
#          1.23857697, -1.21042749, -0.02814948,  1.23857697, -1.21042749,
#         -0.02814948,  1.23857697, -1.21042749, -0.02814948,  1.23857697,
#         -1.21042749, -0.02814948,  1.23857697, -1.21042749, -0.02814948,
#          1.23857697, -1.21042749, -0.02814948,  1.23857697, -1.21042749,
#         -0.02814948,  1.23857697, -1.21042749, -0.02814948,  1.23857697,
#         -1.21042749, -0.02814948,  1.23857697, -1.21042749, -0.02814948,
# ...

# %%
# Calcular la covarianza de las variables
cov_matrix = np.cov(exercise_scaled.T)
cov_matrix
# Out:
# array([[1.01123596, 0.31389536],
#        [0.31389536, 1.01123596]])

# %%
# Graficar la matriz de correlación
plt.figure(figsize=(10, 10))
sns.heatmap(
    cov_matrix,
    cbar=True,
    annot=True,
    square=True,
    fmt='.2f',
    annot_kws={'size': 10},
    xticklabels=['time', 'pulse'],
    yticklabels=['time', 'pulse']
)
plt.tight_layout()
plt.show()

# %%
# Para el dataset "car_crashes"
car_crashes = sns.load_dataset('car_crashes')
car_crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
# visualización de la matriz de correlación
sns.pairplot(car_crashes, hue='abbrev',corner=True,kind='scatter')
plt.show()

# %%
# Normalizamos los datos
scaler = StandardScaler()
car_crashes_scaled = scaler.fit_transform(car_crashes[['total', 'speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses']])
car_crashes_scaled
# Out:
# array([[ 0.73744574,  1.1681476 ,  0.43993758,  1.00230055,  0.27769155,
#         -0.58008306,  0.4305138 ],
#        [ 0.56593556,  1.2126951 , -0.21131068,  0.60853209,  0.80725756,
#          0.94325764, -0.02289992],
#        [ 0.68844283,  0.75670887,  0.18761539,  0.45935701,  1.03314134,
#          0.0708756 , -0.98177845],
#        [ 1.61949811, -0.48361373,  0.54740815,  1.67605228,  1.95169961,
#         -0.33770122,  0.32112519],
#        [-0.92865317, -0.39952407, -0.8917629 , -0.594276  , -0.89196792,
#         -0.04841772,  1.26617765],
#        [-0.5366299 ,  0.01692   , -0.63009543, -0.63369765, -0.29104195,
#         -0.2914793 ,  0.22027622],
#        [-1.22267063, -0.01511416, -0.5833691 , -0.9356316 , -1.38129335,
#          1.02964051,  1.32270187],
#        [ 0.10040792,  0.57951992, -0.01564416,  0.1166575 ,  0.54542553,
#          1.42128062,  0.6907692 ],
#        [-2.42324191, -1.49769509, -1.92383077, -1.71868879, -2.17430102,
# ...

# %%
# Hallar la matriz transpuesta
car_crashes_scaled.T
# Out:
# array([[ 0.73744574,  0.56593556,  0.68844283,  1.61949811, -0.92865317,
#         -0.5366299 , -1.22267063,  0.10040792, -2.42324191,  0.51693265,
#         -0.04660081,  0.41892683, -0.12010517, -0.73264154, -0.31611681,
#         -0.02209935,  0.4924312 ,  1.37448356,  1.15397047, -0.16910808,
#         -0.8061459 , -1.85970845, -0.41412263, -1.51668808,  0.44342829,
#          0.07590647,  1.37448356, -0.21811099, -0.2671139 , -1.02665899,
#         -1.12466481,  0.63943992, -0.85514881,  0.24741665,  1.98701993,
#         -0.41412263,  1.00696174, -0.73264154,  0.59043701, -1.14916626,
#          1.98701993,  0.88445447,  0.90895592,  0.88445447, -1.10016336,
#         -0.5366299 , -0.75714299, -1.27167354,  1.96251847, -0.48762699,
#          0.39442538],
#        [ 1.1681476 ,  1.2126951 ,  0.75670887, -0.48361373, -0.39952407,
#          0.01692   , -0.01511416,  0.57951992, -1.49769509, -0.62025945,
#         -1.01818377,  2.22827806,  0.25517406, -0.1953063 , -0.68733097,
# ...

# %%
# Calcular la covarianza de las variables
cov_matrix = np.cov(car_crashes_scaled.T)
cov_matrix
# Out:
# array([[ 1.02      ,  0.62377855,  0.86966548,  0.84411156,  0.97530276,
#         -0.20369598, -0.0367313 ],
#        [ 0.62377855,  1.02      ,  0.68311294,  0.5997706 ,  0.58341504,
#         -0.07922815, -0.06724637],
#        [ 0.86966548,  0.68311294,  1.02      ,  0.74747271,  0.79919034,
#         -0.17402421, -0.11479767],
#        [ 0.84411156,  0.5997706 ,  0.74747271,  1.02      ,  0.76225267,
#         -0.17835339, -0.07748913],
#        [ 0.97530276,  0.58341504,  0.79919034,  0.76225267,  1.02      ,
#         -0.1600331 , -0.00648582],
#        [-0.20369598, -0.07922815, -0.17402421, -0.17835339, -0.1600331 ,
#          1.02      ,  0.63557877],
#        [-0.0367313 , -0.06724637, -0.11479767, -0.07748913, -0.00648582,
#          0.63557877,  1.02      ]])

# %%
# Graficar la matriz de correlación
plt.figure(figsize=(10, 10))
sns.heatmap(
    cov_matrix,
    cbar=True,
    annot=True,
    square=True,
    fmt='.2f',
    annot_kws={'size': 10},
    xticklabels=['total', 'speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses'],
    yticklabels=['total', 'speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses']
)
# Out:
# <Axes: >

# %%
# realizar un informe donde presenten sus hallazgos y ver similitudes y diferencias en el comportamiento de ambos datasets.
# Hallazgos
# En el dataset "exercise" se observa que a medida que aumenta el tiempo de ejercicio, la frecuencia cardíaca también aumenta.
# En el dataset "car_crashes" se observa que a medida que aumenta el consumo de alcohol, el total de accidentes también aumenta.
# Similitudes
# Ambos datasets presentan una correlación positiva entre las variables.
# Diferencias
# En el dataset "exercise" se observa una correlación positiva entre las variables "time" y "pulse".
# En el dataset "car_crashes" se observa una correlación positiva entre las variables "alcohol" y "total".
# En el dataset "car_crashes" se observa una correlación negativa entre las variables "speeding" y "total".
# En el dataset "car_crashes" se observa una correlación positiva entre las variables "not_distracted" y "total".
# En el dataset "car_crashes" se observa una correlación positiva entre las variables "no_previous" y "total".
# En el dataset "car_crashes" se observa una correlación positiva entre las variables "ins_premium" y "total".

# En conclusión, ambos datasets presentan una correlación positiva entre las variables, sin embargo, las variables que presentan correlación positiva son diferentes en cada dataset.
