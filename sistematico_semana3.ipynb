# %%
import pandas as pd

# %% [markdown]
# •	Generar un DataFrame con los datos del fichero.

# %%
df = pd.read_csv("supermarket_sales.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# •	Mostrar por pantalla las dimensiones del DataFrame, el número de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, las 7 primeras filas y las 7 últimas filas

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.head(7)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
# ...

# %%
df.tail(7)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 993  690-01-6631      B   Mandalay        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 993     Fashion accessories       17.49        10   8.7450   183.6450
# 994  Electronic accessories       60.95         1   3.0475    63.9975
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# ...

# %% [markdown]
# •	¿Cuántas filas y columnas hay en el conjunto de datos?

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# •	¿Conoce los tipos de datos de cada característica/variable y si tienen valores nulos?

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# •	Cambie el tipo de datos de fecha a “date” y configure “Date” como el índice del dataframe

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)

# %%
df.head()
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155  340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880  489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085  634.3785
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# ...

# %% [markdown]
# •	Muestre las estadísticas descriptivas del dataset. Observa a detalle las estadísticas e identifica si existen diferencias altas entre cada percentil y en los percentiles extremos con valores máximos y mínimos de cada característica/variable.

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %% [markdown]
# •	¿Cuántas transacciones se realizaron utilizando 'Ewallet' como método de pago?

# %%
df[df['Payment']== 'Ewallet'].value_counts().shape[0]
# Out:
# 345

# %% [markdown]
# •	¿Cuál es el producto más vendido (con la cantidad más alta) en una sola transacción?

# %%
df.groupby('Product line')['Quantity'].max().head(1)
# Out:
# Product line
# Electronic accessories    10
# Name: Quantity, dtype: int64

# %% [markdown]
# •	¿Cuál es la cantidad de la segunda transacción más reciente?

# %%
# •	¿Cuál es la cantidad de la segunda transacción más reciente
df.groupby('Date')['Quantity'].max().tail(-1)
# Out:
# Date
# 1/10/2019     9
# 1/11/2019     9
# 1/12/2019    10
# 1/13/2019    10
# 1/14/2019    10
#              ..
# 3/5/2019     10
# 3/6/2019     10
# 3/7/2019      9
# 3/8/2019     10
# 3/9/2019     10
# Name: Quantity, Length: 88, dtype: int64

# %% [markdown]
# •	¿Cuál es el valor de 'Gross Income' para las transacciones con un rating superior a 9 y que sean pagadas con Ewallet?

# %%
df[(df['Rating'] > 9) & (df['Payment'] == 'Ewallet')]['gross income']
# Out:
# Date
# 2019-01-05    26.1415
# 2019-02-17     8.6400
# 2019-02-03    24.7815
# 2019-01-07    29.2830
# 2019-01-22    33.6015
# 2019-03-23     7.9125
# 2019-03-16    29.0000
# 2019-02-10    15.0700
# 2019-02-07     4.9440
# 2019-03-07    12.5700
# 2019-03-27    28.0170
# 2019-01-28    13.0200
# 2019-02-10     3.7035
# 2019-01-31     7.4120
# 2019-02-05     6.9330
# 2019-02-15     4.5780
# 2019-01-30    24.2575
# 2019-02-06    19.3960
# 2019-01-06    10.2350
# 2019-01-27    24.3315
# 2019-02-04     0.6990
# 2019-02-22     9.9375
# 2019-03-22    20.3720
# 2019-01-22     4.0755
# 2019-01-20    16.5860
# 2019-01-08     0.6390
# 2019-02-04    34.9560
# 2019-01-05     1.5950
# 2019-01-28     9.6720
# 2019-01-27    18.9980
# 2019-03-29    13.7150
# 2019-03-01     3.4730
# 2019-01-22     4.6020
# 2019-01-27     8.4840
# 2019-03-24     7.0320
# 2019-01-11    14.5500
# 2019-02-07    24.1640
# 2019-01-20     6.2480
# 2019-02-08     0.9850
# 2019-02-20     3.7690
# 2019-01-20    25.5520
# ...

# %% [markdown]
# •	¿Cuál es el promedio del impuesto del 5% (Tax 5%) para las transacciones realizadas en Naypyitaw?

# %%
df.query('City == "Naypyitaw"')['Tax 5%'].mean()
# Out:
# 16.05236737804878

# %%
df[df['City'] == 'Naypyitaw']['Tax 5%'].mean()
# Out:
# 16.05236737804878

# %% [markdown]
# •	¿Cuál es la cantidad total de ingresos (Total) para las transacciones realizadas por clientes de tipo 'Member' y que sean de la categoría 'Health and Beauty'?

# %%
df[(df['Customer type'] == 'Member') & (df['Product line']=='Health and beauty')]['Total'].sum()
# Out:
# 25831.0395

# %% [markdown]
# •	Seleccionar las transacciones donde la cantidad (Quantity) es mayor que 5 y el total (Total) es mayor que 200

# %%
df[df['Quantity'] >5][df['Total']>200].sort_values(by='Quantity',ascending=True)
# Out:
# /var/folders/03/fv0q_y693gq6wh4vl8097rqh0000gn/T/ipykernel_88276/2869709350.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Quantity'] >5][df['Total']>200].sort_values(by='Quantity',ascending=True)
#       Invoice ID Branch       City Customer type  Gender  \
# 133  590-83-4591      B   Mandalay        Member    Male
# 549  213-32-1216      A     Yangon        Normal  Female
# 558  712-39-0363      A     Yangon        Member    Male
# 563  760-90-2357      A     Yangon        Member    Male
# 159  423-57-2993      B   Mandalay        Normal    Male
# ..           ...    ...        ...           ...     ...
# 635  188-55-0967      B   Mandalay        Member    Male
# 141  280-17-4359      C  Naypyitaw        Member    Male
# 140  731-81-9469      C  Naypyitaw        Member  Female
# 146  685-64-1609      A     Yangon        Member  Female
# 138  241-72-9525      B   Mandalay        Normal    Male
#
# ...

# %% [markdown]
# •	Seleccionar las primeras diez filas y columnas de la 2 a la 6

# %%
df.iloc[:10,0:6]
# Out:
#     Invoice ID Branch       City Customer type  Gender            Product line
# 0  750-67-8428      A     Yangon        Member    Male       Health and beauty
# 1  226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon        Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon        Normal    Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw        Normal    Male  Electronic accessories
# 6  355-53-5943      A     Yangon        Member  Female  Electronic accessories
# 7  315-22-5665      C  Naypyitaw        Normal  Female      Home and lifestyle
# 8  665-32-9167      A     Yangon        Member  Female       Health and beauty
# 9  692-92-5582      B   Mandalay        Member  Female      Food and beverages

# %%
# •	Cambio de 'Gender' a 'Female' en la fila con 'Invoice ID' igual a '750-67-8428'. 
df.loc[df['Invoice ID'] == '750-67-8428', 'Gender'] = 'Female'
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member    Male
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# •	Seleccionar filas con fecha posterior al 15 de febrero de 2019 y Customer type igual a "Member"

# %%
df[df['Date']>'2/15/2019']
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %% [markdown]
# 18.	Eliminar las columnas Time y Payment

# %%
df_copy = df

# %%
df_copy.drop(['Time', 'Payment'], axis=1, inplace=True)
df_copy.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member    Male
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#      cogs  gross margin percentage  gross income  Rating
# 0  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 19.	Borrar la fila con 'Invoice ID' igual a '226-31-3081'

# %%
df_copy.drop(df_copy[df_copy['Invoice ID'] == '226-31-3081'].index, inplace=True)
df_copy.head()
# Out:
#     Invoice ID Branch       City Customer type Gender            Product line  \
# 0  750-67-8428      A     Yangon        Member   Male       Health and beauty
# 2  631-41-3108      A     Yangon        Normal   Male      Home and lifestyle
# 3  123-19-1176      A     Yangon        Member   Male       Health and beauty
# 4  373-73-7910      A     Yangon        Normal   Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw        Normal   Male  Electronic accessories
#
#    Unit price  Quantity   Tax 5%     Total       Date    cogs  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  522.83
# 2       46.33         7  16.2155  340.5255   3/3/2019  324.31
# 3       58.22         8  23.2880  489.0480  1/27/2019  465.76
# 4       86.31         7  30.2085  634.3785   2/8/2019  604.17
# 5       85.39         7  29.8865  627.6165  3/25/2019  597.73
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 20.	Aumentar el 'Unit price' en un 10% si el 'Gender' es 'Female'

# %%
df_copy.loc[df_copy['Gender'] == 'Female', 'Unit price'] *= 1.10
df_copy[df_copy['Gender'] == 'Female']
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 6    Electronic accessories  216.049409         6  20.6520   433.6920
# 7        Home and lifestyle  230.862791        10  36.7800   772.3800
# ...

# %% [markdown]
# 21.	borrar las filas con 'Quantity' igual a 1

# %%
df_copy.drop(df_copy[df_copy['Quantity'] == 1].index, inplace=True)
df_copy.head()
# Out:
#     Invoice ID Branch       City Customer type Gender            Product line  \
# 0  750-67-8428      A     Yangon        Member   Male       Health and beauty
# 2  631-41-3108      A     Yangon        Normal   Male      Home and lifestyle
# 3  123-19-1176      A     Yangon        Member   Male       Health and beauty
# 4  373-73-7910      A     Yangon        Normal   Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw        Normal   Male  Electronic accessories
#
#    Unit price  Quantity   Tax 5%     Total       Date    cogs  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  522.83
# 2       46.33         7  16.2155  340.5255   3/3/2019  324.31
# 3       58.22         8  23.2880  489.0480  1/27/2019  465.76
# 4       86.31         7  30.2085  634.3785   2/8/2019  604.17
# 5       85.39         7  29.8865  627.6165  3/25/2019  597.73
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 22.	Renombrar 'cogs' a 'COGS' y 'gross income' a 'Gross Income'

# %%
# 22.	Renombrar 'cogs' a 'COGS' y 'gross income' a 'Gross Income'
df_copy.rename(columns={'cogs': 'COGS', 'gross income': 'Gross Income'}, inplace=True)
df_copy.head()

# %% [markdown]
# 23.	Verificar si hay datos nulos en el dataframe, contarlos y darle su debido tratamiento

# %%
# 23.	Verificar si hay datos nulos en el dataframe, contarlos y darle su debido tratamiento 
df_copy.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df_copy.dropna(inplace=True)

# %%
df_copy.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# 24.	Convertir todos los valores de Product line a minúsculas

# %%
df_copy['Product line'] = df_copy['Product line'].str.lower()
df_copy.head()
# Out:
#     Invoice ID Branch       City Customer type Gender            Product line  \
# 0  750-67-8428      A     Yangon        Member   Male       health and beauty
# 2  631-41-3108      A     Yangon        Normal   Male      home and lifestyle
# 3  123-19-1176      A     Yangon        Member   Male       health and beauty
# 4  373-73-7910      A     Yangon        Normal   Male       sports and travel
# 5  699-14-3026      C  Naypyitaw        Normal   Male  electronic accessories
#
#    Unit price  Quantity   Tax 5%     Total       Date    cogs  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  522.83
# 2       46.33         7  16.2155  340.5255   3/3/2019  324.31
# 3       58.22         8  23.2880  489.0480  1/27/2019  465.76
# 4       86.31         7  30.2085  634.3785   2/8/2019  604.17
# 5       85.39         7  29.8865  627.6165  3/25/2019  597.73
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 25.	Mostrar las filas donde Product line es “Health and beauty” y Quantity mayor a 5

# %%
df_copy[df_copy['Product line']=='health and beauty'][df_copy['Quantity']>5]
# Out:
# /var/folders/03/fv0q_y693gq6wh4vl8097rqh0000gn/T/ipykernel_4412/2535216087.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_copy[df_copy['Product line']=='health and beauty'][df_copy['Quantity']>5]
#       Invoice ID Branch       City Customer type  Gender       Product line  \
# 0    750-67-8428      A     Yangon        Member    Male  health and beauty
# 3    123-19-1176      A     Yangon        Member    Male  health and beauty
# 14   829-34-3910      A     Yangon        Normal  Female  health and beauty
# 16   656-95-9349      A     Yangon        Member  Female  health and beauty
# 29   848-62-7243      A     Yangon        Normal    Male  health and beauty
# ..           ...    ...        ...           ...     ...                ...
# 936  433-08-7822      C  Naypyitaw        Normal  Female  health and beauty
# 944  333-23-2632      A     Yangon        Member    Male  health and beauty
# ...

# %% [markdown]
# 26.	Mostrar las filas donde Total es menor a 100 y Branch es A o B

# %%
# 26.	Mostrar las filas donde Total es menor a 100 y Branch es A o B
df_copy[(df_copy['Total']<100) & (df_copy['Branch']=='A') | (df_copy['Branch']=='B')].sort_values(by='Total',ascending=True)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 273  633-91-1052      A    Yangon        Normal  Female
# 861  840-76-5966      A    Yangon        Member    Male
# 986  764-44-8999      B  Mandalay        Normal  Female
# 231  545-46-3100      B  Mandalay        Member  Female
# 54   242-55-6721      B  Mandalay        Normal    Male
# ..           ...    ...       ...           ...     ...
# 96   766-85-7061      B  Mandalay        Normal    Male
# 209  817-69-8206      B  Mandalay        Normal  Female
# 122  219-22-9386      B  Mandalay        Member    Male
# 792  744-16-7898      B  Mandalay        Normal  Female
# 996  303-96-2227      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 273      home and lifestyle   37.755293         2   1.2030    25.2630
# 861       sports and travel   12.760000         2   1.2760    26.7960
# 986       health and beauty   46.323203         2   1.4760    30.9960
# ...

# %% [markdown]
# 27.	Mostrar las filas donde Payment no es Ewallet y Rating menor o igual a 6

# %%
# 27.	Mostrar las filas donde Payment no es Ewallet y Rating menor o igual a 6
df[(df['Payment']!='Ewallet') & (df['Rating']<=6)].sort_values(by='Rating',ascending=True)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 876  885-56-0389      C  Naypyitaw        Member    Male
# 643  131-15-8856      C  Naypyitaw        Member  Female
# 618  828-46-6863      A     Yangon        Member    Male
# 790  651-96-5970      A     Yangon        Normal    Male
# 328  730-61-8757      B   Mandalay        Member    Male
# ..           ...    ...        ...           ...     ...
# 367  468-88-0009      A     Yangon        Member    Male
# 841  291-59-1384      B   Mandalay        Normal    Male
# 677  274-05-5470      A     Yangon        Member  Female
# 483  305-18-3552      B   Mandalay        Member    Male
# 79   756-01-7507      C  Naypyitaw        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 876     Fashion accessories       52.35         1   2.6175   54.9675
# 643      Food and beverages       72.52         8  29.0080  609.1680
# 618      Food and beverages       98.53         6  29.5590  620.7390
# ...

# %% [markdown]
# 28.	Mostrar las filas donde Customer type es Normal y Tax 5% mayor a 10

# %%
df[(df['Customer type']=='Normal') & (df['Tax 5%']>10)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 12   365-64-0515      A     Yangon        Normal  Female
# ..           ...    ...        ...           ...     ...
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 985  374-38-5555      B   Mandalay        Normal  Female
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ...

# %% [markdown]
# 29.	Mostrar las filas donde fecha anterior al 1 de marzo de 2019 y Payment Cash

# %%
df[(df['Date']<'3/1/2019') & (df['Payment']=='Cash')]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 15   299-46-1805      B   Mandalay        Member  Female
# 26   649-29-6775      B   Mandalay        Normal    Male
# 28   145-94-9061      B   Mandalay        Normal  Female
# 31   149-71-6266      B   Mandalay        Member    Male
# 32   640-49-2076      B   Mandalay        Normal    Male
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 15        Sports and travel       93.72         6  28.1160  590.4360
# 26      Fashion accessories       33.52         1   1.6760   35.1960
# 28       Food and beverages       88.36         5  22.0900  463.8900
# ...

# %% [markdown]
# 30.	Mostrar las filas donde año de la fecha es 2019 y mes diciembre (mes 12)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[(df['Date'].dt.year == 2019)&(df['Date'].dt.month == 12)]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# 31.	Convierte todos los valores de "Product line" a mayúsculas.

# %%
df['Product line']=df['Product line'].str.upper()
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       HEALTH AND BEAUTY       74.69         7  26.1415  548.9715 2019-01-05
# 1  ELECTRONIC ACCESSORIES       15.28         5   3.8200   80.2200 2019-03-08
# 2      HOME AND LIFESTYLE       46.33         7  16.2155  340.5255 2019-03-03
# 3       HEALTH AND BEAUTY       58.22         8  23.2880  489.0480 2019-01-27
# 4       SPORTS AND TRAVEL       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 32.	Agrega un guion "-" al final de cada valor de "Branch".

# %%
df['Branch'] = df['Branch'].apply(lambda x: x + '-')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428     A-     Yangon        Member  Female
# 1    226-31-3081     C-  Naypyitaw        Normal  Female
# 2    631-41-3108     A-     Yangon        Normal    Male
# 3    123-19-1176     A-     Yangon        Member    Male
# 4    373-73-7910     A-     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758     C-  Naypyitaw        Normal    Male
# 996  303-96-2227     B-   Mandalay        Normal  Female
# 997  727-02-1313     A-     Yangon        Member    Male
# 998  347-56-2442     A-     Yangon        Normal    Male
# 999  849-09-3807     A-     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# 33.	Elimina los espacios en blanco al principio y al final de cada valor de "Customer type".

# %%
df['Customer type'] = df['Customer type'].str.strip()
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428     A-     Yangon        Member  Female
# 1  226-31-3081     C-  Naypyitaw        Normal  Female
# 2  631-41-3108     A-     Yangon        Normal    Male
# 3  123-19-1176     A-     Yangon        Member    Male
# 4  373-73-7910     A-     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 34.	Concatena las columnas "City" y "Branch

# %%
City = df['City']
branch = df['Branch']
df['City-Branch'] = City + '-' + branch
df['City-Branch']
# Out:
# 0         Yangon-A-
# 1      Naypyitaw-C-
# 2         Yangon-A-
# 3         Yangon-A-
# 4         Yangon-A-
#            ...
# 995    Naypyitaw-C-
# 996     Mandalay-B-
# 997       Yangon-A-
# 998       Yangon-A-
# 999       Yangon-A-
# Name: City-Branch, Length: 1000, dtype: object
